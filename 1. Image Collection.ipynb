# %% [markdown]
# # 1. Import Dependencies

# %%
# !pip install opencv-python

# %%
# Import opencv
import cv2 

# Import uuid
import uuid

# Import Operating System
import os

# Import time
import time

# %% [markdown]
# # 2. Define Images to Collect

# %%
labels = ['thumbsup', 'thumbsdown', 'thankyou', 'livelong']
number_imgs = 5

# %% [markdown]
# # 3. Setup Folders

# %%
IMAGES_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'collectedimages')

# %%
os.name
# Out:
# 'posix'

# %%
if not os.path.exists(IMAGES_PATH):
    if os.name == 'posix':
        # !mkdir -p {IMAGES_PATH}
    if os.name == 'nt':
         # !mkdir {IMAGES_PATH}
for label in labels:
    path = os.path.join(IMAGES_PATH, label)
    if not os.path.exists(path):
        # !mkdir {path}

# %% [markdown]
# # 4. Capture Images

# %%
#cap.release()
#cv2.destroyAllWindows()

# %%
for label in labels:
#    cap = cv2.VideoCapture(4)
    cap = cv2.VideoCapture(0)
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    for imgnum in range(number_imgs):
        print('Collecting image {}'.format(imgnum))
        ret, frame = cap.read()
        imgname = os.path.join(IMAGES_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imgname, frame)
        cv2.imshow('frame', frame)
        time.sleep(2)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# Collecting images for thumbsup
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# [ WARN:0] global /tmp/pip-req-build-3129w7z7/opencv/modules/videoio/src/cap_v4l.cpp (890) open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# Collecting images for thumbsdown
# Collecting image 0
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_4536/952772324.py in <module>
#       8         ret, frame = cap.read()
#       9         imgname = os.path.join(IMAGES_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
# ---> 10         cv2.imwrite(imgname, frame)
#      11         cv2.imshow('frame', frame)
#      12         time.sleep(2)
#
# error: OpenCV(4.5.4) /tmp/pip-req-build-3129w7z7/opencv/modules/imgcodecs/src/loadsave.cpp:799: error: (-215:Assertion failed) !_img.empty() in function 'imwrite'

# %% [markdown]
# # 5. Image Labelling

# %%
# !pip install --upgrade pyqt5 lxml
# Out:
# Requirement already satisfied: pyqt5 in /home/vikesh/miniconda3/envs/tfod/lib/python3.7/site-packages (5.15.6)
# Requirement already satisfied: lxml in /home/vikesh/miniconda3/envs/tfod/lib/python3.7/site-packages (4.6.4)
# Requirement already satisfied: PyQt5-sip<13,>=12.8 in /home/vikesh/miniconda3/envs/tfod/lib/python3.7/site-packages (from pyqt5) (12.9.0)
# Requirement already satisfied: PyQt5-Qt5>=5.15.2 in /home/vikesh/miniconda3/envs/tfod/lib/python3.7/site-packages (from pyqt5) (5.15.2)

# %%
LABELIMG_PATH = os.path.join('Tensorflow', 'labelimg')

# %%
if not os.path.exists(LABELIMG_PATH):
    # !mkdir {LABELIMG_PATH}
    # !git clone https://github.com/tzutalin/labelImg {LABELIMG_PATH}

# %%
if os.name == 'posix':
    # !make qt5py3
if os.name =='nt':
    # !cd {LABELIMG_PATH} && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# make: *** No rule to make target 'qt5py3'.  Stop.

# %%
# !cd {LABELIMG_PATH} && python labelImg.py
# Out:
# Traceback (most recent call last):
#   File "labelImg.py", line 33, in <module>
#     from libs.resources import *
# ModuleNotFoundError: No module named 'libs.resources'

# %% [markdown]
# # 6. Move them into a Training and Testing Partition

# %% [markdown]
# # OPTIONAL - 7. Compress them for Colab Training

# %%
TRAIN_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'train')
TEST_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'test')
ARCHIVE_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'archive.tar.gz')

# %%
# !tar -czf {ARCHIVE_PATH} {TRAIN_PATH} {TEST_PATH}
# Out:
# tar: Tensorflow/workspace/images/train: Cannot stat: No such file or directory
# tar: Tensorflow/workspace/images/test: Cannot stat: No such file or directory
# tar: Exiting with failure status due to previous errors
